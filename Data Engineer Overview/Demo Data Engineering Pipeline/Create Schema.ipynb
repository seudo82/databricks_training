-- %% [markdown]
-- **Create Schema for the Raw, Bronze, Silver, and Gold tables**

-- %%
CREATE SCHEMA IF NOT EXISTS workspace.00_raw;

CREATE SCHEMA IF NOT EXISTS workspace.01_bronze;

CREATE SCHEMA IF NOT EXISTS workspace.02_silver;

CREATE SCHEMA IF NOT EXISTS workspace.03_gold;
